# %% [markdown]
# ## FCFS Scheduling Visualizations
# Project for Computer Networks,
# IBU MsC 2023/24
#
#
# https://github.com/jinnosux/ProcessSchedulingVisualizations
#
# **Requirement** - Make sure you set Runtime type to **Python3** and use **GPU Hardware Accelerator** (Edit > Notebook Settings)

# %% [markdown]
# Fix MatPlotLib rendering issue

# %%
# %matplotlib inline

# %% [markdown]
# Clone the git repo:

# %%
# !git clone https://github.com/jinnosux/ProcessSchedulingVisualizations.git

# %% [markdown]
# Navigate inside the folder

# %%
# %cd ProcessSchedulingVisualizations

# %% [markdown]
# Run the script

# %%
# %run project.py
